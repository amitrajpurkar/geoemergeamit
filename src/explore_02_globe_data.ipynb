# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap

mosquito = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/globe_mosquito.zip')
land_cover = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/globe_land_cover.zip')

# %%
fl = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/florida_boundary.geojson')[['geometry']]

mosquito = gpd.sjoin(mosquito, fl, how="inner", predicate='intersects') \
          .drop(columns=['index_right']) \
          .reset_index(drop=True)

land_cover = gpd.sjoin(land_cover, fl, how="inner", predicate='intersects') \
          .drop(columns=['index_right']) \
          .reset_index(drop=True)

# %%
# List of columns we have access to
mosquito.columns
# Out:
# Index(['CountryCode', 'CountryName', 'Elevation', 'AbdomenCloseupPhotoUrls',
#        'BreedingGroundEliminated', 'Comments', 'DataSource', 'ExtraData',
#        'Genus', 'GlobeTeams', 'LarvaFullBodyPhotoUrls', 'LarvaeCount',
#        'LastIdentifyStage', 'LocationAccuracyM', 'LocationMethod',
#        'MeasuredAt', 'MeasurementElevation', 'MeasurementLatitude',
#        'MeasurementLongitude', 'MosquitoAdults', 'MosquitoEggs',
#        'MosquitoHabitatMapperId', 'MosquitoPupae', 'Species', 'Userid',
#        'WaterSource', 'WaterSourcePhotoUrls', 'WaterSourceType',
#        'OrganizationId', 'OrganizationName', 'Protocol', 'SiteId', 'SiteName',
#        'MeasuredDate', 'LarvaeCountProcessed', 'geometry'],
#       dtype='str')

# %%
# Create empty map zoomed to Florida
map = folium.Map(location=[28.263363, -83.497652], tiles="Cartodb dark_matter", zoom_start=7)

# Add each point as a marker on the map
for idx, row in mosquito.iterrows():
    popup_content = f"<b>Date:</b> {row['MeasuredDate']}<br><b>Water Source:</b> {row['WaterSourceType']}<br><b>Longitude:</b> {row['MeasurementLongitude']}<br><b>Latitude:</b> {row['MeasurementLatitude']}"
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=folium.Popup(popup_content, max_width=300)
    ).add_to(map)

display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd60be50df54b88606cb3f8462d9dbd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd60be50df54b88606cb3f8462d9dbd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd60be50df54b88606cb3f8462d9dbd7 = L.map(
#                 &quot;map_bd60be50df54b88606cb3f8462d9dbd7&quot;,
#                 {
#                     center: [28.263363, -83.497652],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acb1cd982dbff745f04f149cc2a8ef11 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acb1cd982dbff745f04f149cc2a8ef11.addTo(map_bd60be50df54b88606cb3f8462d9dbd7);
#
#
#             var marker_030293dfaf2c5c9202457f5d96859f87 = L.marker(
#                 [28.104842, -82.479132],
#                 {
# }
#             ).addTo(map_bd60be50df54b88606cb3f8462d9dbd7);
#
#
#         var popup_eba09bbf70cb3e5080f955c3648dd657 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_db66691cc4c61c95a3e0049385d7beed = $(`&lt;div id=&quot;html_db66691cc4c61c95a3e0049385d7beed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.479&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1054&lt;/div&gt;`)[0];
#                 popup_eba09bbf70cb3e5080f955c3648dd657.setContent(html_db66691cc4c61c95a3e0049385d7beed);
#
#
#
#         marker_030293dfaf2c5c9202457f5d96859f87.bindPopup(popup_eba09bbf70cb3e5080f955c3648dd657)
#         ;
#
#
#
#
#             var marker_3f0617c4f8ce659a659e5d46ba936e5b = L.marker(
#                 [28.10394, -82.479119],
#                 {
# }
#             ).addTo(map_bd60be50df54b88606cb3f8462d9dbd7);
#
#
#         var popup_7ce7a59316899431a4218b1c1326e9b6 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_37f8fae604c2bcb30bbf622932e3c5d9 = $(`&lt;div id=&quot;html_37f8fae604c2bcb30bbf622932e3c5d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; flowing: still water found next to river or stream&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.4784&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1042&lt;/div&gt;`)[0];
#                 popup_7ce7a59316899431a4218b1c1326e9b6.setContent(html_37f8fae604c2bcb30bbf622932e3c5d9);
#
#
#
#         marker_3f0617c4f8ce659a659e5d46ba936e5b.bindPopup(popup_7ce7a59316899431a4218b1c1326e9b6)
#         ;
#
#
#
#
#             var marker_5350cff03a78ae8255410a6b15ab0dbd = L.marker(
#                 [28.103918, -82.481155],
#                 {
# }
#             ).addTo(map_bd60be50df54b88606cb3f8462d9dbd7);
#
#
#         var popup_2d2e43fe804026d0293616e256fedc27 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_3c2ee7ca9c7e70d24728244e8cf1f115 = $(`&lt;div id=&quot;html_3c2ee7ca9c7e70d24728244e8cf1f115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.4807&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1045&lt;/div&gt;`)[0];
#                 popup_2d2e43fe804026d0293616e256fedc27.setContent(html_3c2ee7ca9c7e70d24728244e8cf1f115);
#
#
#
#         marker_5350cff03a78ae8255410a6b15ab0dbd.bindPopup(popup_2d2e43fe804026d0293616e256fedc27)
#         ;
#
#
#
#
#             var marker_30c964c45a897dde381797dd4e5a20b1 = L.marker(
#                 [27.714311, -82.690862],
#                 {
# }
#             ).addTo(map_bd60be50df54b88606cb3f8462d9dbd7);
#
#
#         var popup_5af15dc1599063f27901780d871a4eeb = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e2af9d22daf070389bf5159253fcc29d = $(`&lt;div id=&quot;html_e2af9d22daf070389bf5159253fcc29d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-16&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.69&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.7144&lt;/div&gt;`)[0];
#                 popup_5af15dc1599063f27901780d871a4eeb.setContent(html_e2af9d22daf070389bf5159253fcc29d);

# %%
# List of columns we have access to
land_cover.columns
# Out:
# Index(['CountryCode', 'CountryName', 'Elevation', 'DataSource',
#        'DownwardCaption', 'DownwardExtraData', 'DownwardPhotoUrl', 'DryGround',
#        'EastCaption', 'EastClassifications', 'EastExtraData', 'EastPhotoUrl',
#        'Feature1Caption', 'Feature1ExtraData', 'Feature1PhotoUrl',
#        'Feature2Caption', 'Feature2ExtraData', 'Feature2PhotoUrl',
#        'Feature3Caption', 'Feature3ExtraData', 'Feature3PhotoUrl',
#        'Feature4Caption', 'Feature4ExtraData', 'Feature4PhotoUrl',
#        'FieldNotes', 'GlobeTeams', 'LandCoverId', 'LeavesOnTrees',
#        'LocationAccuracyM', 'LocationMethod', 'MeasuredAt',
#        'MeasurementElevation', 'MeasurementLatitude', 'MeasurementLongitude',
#        'MucCode', 'MucDescription', 'MucDetails', 'Muddy', 'NorthCaption',
#        'NorthClassifications', 'NorthExtraData', 'NorthPhotoUrl',
#        'RainingSnowing', 'SnowIce', 'SouthCaption', 'SouthClassifications',
#        'SouthExtraData', 'SouthPhotoUrl', 'StandingWater', 'UpwardCaption',
#        'UpwardExtraData', 'UpwardPhotoUrl', 'Userid', 'WestCaption',
#        'WestClassifications', 'WestExtraData', 'WestPhotoUrl',
#        'OrganizationId', 'OrganizationName', 'Protocol', 'SiteId', 'SiteName',
#        'MeasuredDate', 'geometry'],
#       dtype='str')

# %%
# Create empty map zoomed to Florida
map = folium.Map(location=[28.263363, -83.497652], tiles="Cartodb dark_matter", zoom_start=7)

# Add each point as a marker on the map
for idx, row in land_cover.iterrows():
    popup_content = f"<b>Date:</b> {row['MeasuredDate']}<br><b>MUC:</b> {row['MucDescription']}<br><b>Longitude:</b> {row['MeasurementLongitude']}<br><b>Latitude:</b> {row['MeasurementLatitude']}"
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=folium.Popup(popup_content, max_width=300)
    ).add_to(map)

display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4345db045ea103181307e625d4a8409b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4345db045ea103181307e625d4a8409b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4345db045ea103181307e625d4a8409b = L.map(
#                 &quot;map_4345db045ea103181307e625d4a8409b&quot;,
#                 {
#                     center: [28.263363, -83.497652],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09df94219105b3188bf0fc63e916a1fd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09df94219105b3188bf0fc63e916a1fd.addTo(map_4345db045ea103181307e625d4a8409b);
#
#
#             var marker_b7d3cd22d544a796f9a6da1d03cc4707 = L.marker(
#                 [30.374141, -86.223606],
#                 {
# }
#             ).addTo(map_4345db045ea103181307e625d4a8409b);
#
#
#         var popup_10a6b403414c14cb80b754fca1423b00 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2f73650d7130e9ea7fef0d9f8dce2403 = $(`&lt;div id=&quot;html_2f73650d7130e9ea7fef0d9f8dce2403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-12&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; Urban, Commercial Property&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -86.2233&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 30.3748&lt;/div&gt;`)[0];
#                 popup_10a6b403414c14cb80b754fca1423b00.setContent(html_2f73650d7130e9ea7fef0d9f8dce2403);
#
#
#
#         marker_b7d3cd22d544a796f9a6da1d03cc4707.bindPopup(popup_10a6b403414c14cb80b754fca1423b00)
#         ;
#
#
#
#
#             var marker_162559512f31f43f2b5152bbde8a3433 = L.marker(
#                 [27.967085, -81.924205],
#                 {
# }
#             ).addTo(map_4345db045ea103181307e625d4a8409b);
#
#
#         var popup_1d584132f2ef9a3e56b4926cf0069468 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d974692f6b75cd20def0104c4ed0ea99 = $(`&lt;div id=&quot;html_d974692f6b75cd20def0104c4ed0ea99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.9671&lt;/div&gt;`)[0];
#                 popup_1d584132f2ef9a3e56b4926cf0069468.setContent(html_d974692f6b75cd20def0104c4ed0ea99);
#
#
#
#         marker_162559512f31f43f2b5152bbde8a3433.bindPopup(popup_1d584132f2ef9a3e56b4926cf0069468)
#         ;
#
#
#
#
#             var marker_ad6c71473d48f69195ea25b234840550 = L.marker(
#                 [27.966182, -81.924197],
#                 {
# }
#             ).addTo(map_4345db045ea103181307e625d4a8409b);
#
#
#         var popup_f8266c5dd1bc49976bee5f21628fc634 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a10dce3e401afe7d13ca82ce5d7a194e = $(`&lt;div id=&quot;html_a10dce3e401afe7d13ca82ce5d7a194e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.967&lt;/div&gt;`)[0];
#                 popup_f8266c5dd1bc49976bee5f21628fc634.setContent(html_a10dce3e401afe7d13ca82ce5d7a194e);
#
#
#
#         marker_ad6c71473d48f69195ea25b234840550.bindPopup(popup_f8266c5dd1bc49976bee5f21628fc634)
#         ;
#
#
#
#
#             var marker_dfe9e23ec96d68f84313984d28a3bff4 = L.marker(
#                 [27.967085, -81.924205],
#                 {
# }
#             ).addTo(map_4345db045ea103181307e625d4a8409b);
#
#
#         var popup_76b87b1ef59eabebafa435c50f23fe91 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_13b9c7d2f1a1bf261d4c642fe1b5a8b2 = $(`&lt;div id=&quot;html_13b9c7d2f1a1bf261d4c642fe1b5a8b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.9671&lt;/div&gt;`)[0];
#                 popup_76b87b1ef59eabebafa435c50f23fe91.setContent(html_13b9c7d2f1a1bf261d4c642fe1b5a8b2);
#
#
#
#         marker_dfe9e23ec96d68f84313984d28a3bff4.bindPopup(popup_76b87b1ef59eabebafa435c50f23fe91)
#         ;
